# %%
import pandas as pd 
import os
from dotenv import load_dotenv

load_dotenv("./.env")
# Out:
# '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'

# %%
df = pd.read_csv('Mental_Health_FAQ.csv')
df
# Out:
#     Question_ID                                          Questions  \
# 0       1590140        What does it mean to have a mental illness?
# 1       2110618                    Who does mental illness affect?
# 2       6361820                        What causes mental illness?
# 3       9434130  What are some of the warning signs of mental i...
# 4       7657263            Can people with mental illness recover?
# ..          ...                                                ...
# 93      4373204            How do I know if I'm drinking too much?
# 94      7807643  If cannabis is dangerous, why are we legalizin...
# 95      4352464       How can I convince my kids not to use drugs?
# 96      6521784  What is the legal status (and evidence) of CBD...
# 97      3221856                    What is the evidence on vaping?
#
#                                               Answers
# 0   Mental illnesses are health conditions that di...
# ...

# %%
df = df[['Questions','Answers']]
df.head(10)
# Out:
#                                            Questions  \
# 0        What does it mean to have a mental illness?
# 1                    Who does mental illness affect?
# 2                        What causes mental illness?
# 3  What are some of the warning signs of mental i...
# 4            Can people with mental illness recover?
# 5  What should I do if I know someone who appears...
# 6  How can I find a mental health professional fo...
# 7              What treatment options are available?
# 8  If I become involved in treatment, what do I n...
# 9  What is the difference between mental health p...
#
#                                              Answers
# 0  Mental illnesses are health conditions that di...
# 1  It is estimated that mental illness affects 1 ...
# 2  It is estimated that mental illness affects 1 ...
# 3  Symptoms of mental health disorders vary depen...
# 4  When healing from mental illness, early identi...
# 5  Although this website cannot substitute for pr...
# ...

# %%
import unicodedata

def remove_unwanted_data(str):
    return str.replace("\xa0", " ")


def fix_unicode(string):
    return unicodedata.normalize("NFKD", string).encode("ascii", "ignore").decode("utf-8")

# %%
df = df.apply(lambda row : remove_unwanted_data(row))

# %%
df
# Out:
#     Question_ID                                          Questions  \
# 0       1590140        What does it mean to have a mental illness?
# 1       2110618                    Who does mental illness affect?
# 2       6361820                        What causes mental illness?
# 3       9434130  What are some of the warning signs of mental i...
# 4       7657263            Can people with mental illness recover?
# ..          ...                                                ...
# 93      4373204            How do I know if I'm drinking too much?
# 94      7807643  If cannabis is dangerous, why are we legalizin...
# 95      4352464       How can I convince my kids not to use drugs?
# 96      6521784  What is the legal status (and evidence) of CBD...
# 97      3221856                    What is the evidence on vaping?
#
#                                               Answers
# 0   Mental illnesses are health conditions that di...
# ...

# %%
data  = []
for _, row in df.iterrows():
    completion = fix_unicode( row['Answers'])
    completion = completion.split('\n')
    completion = ' '.join(completion)
    convo = {'prompt': fix_unicode( row['Questions']),'completion':completion}
    data.append(convo)

# %%
import json
with open('mental_health.jsonl', 'w') as outfile:
        for i in data:
            json.dump(i, outfile)
            outfile.write('\n')

# %%
# !pip3 install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for openai: filename=openai-0.26.1-py3-none-any.whl size=67292 sha256=d311671ba22599d6f626a56c36ff0370f4b97b912b2830ec4642a53a3c53dbf4
#   Stored in directory: /Users/devamacha/Library/Caches/pip/wheels/2a/14/80/3ab4f09abdd053692375894cc2cd43ed0f6bd5edf967333fbc
# Successfully built openai
# ...

# %%
import os
import openai

# set the key
openai.api_key = os.environ.get("OPENAI_API_KEY")


#!openai tools fine_tunes.prepare_data -f 'mental_health.jsonl'

# %%
# !openai api fine_tunes.create -t mental_health_prepared.jsonl -m davinci --suffix "mental health model"
# Out:
# Upload progress: 100%|███████████████████████| 165k/165k [00:00<00:00, 123Mit/s]
# Uploaded file from mental_health_prepared.jsonl: file-nDH27e2EspllFXk9wQ1xOlks
# Created fine-tune: ft-uxJUeShzlHhR97SQFEiI7UYg
# Streaming events until fine-tuning is complete...
#
# (Ctrl-C will interrupt the stream, but not cancel the fine-tune)
# [2023-02-28 13:41:18] Created fine-tune: ft-uxJUeShzlHhR97SQFEiI7UYg
#
# Stream interrupted (client disconnected).
# To resume the stream, run:
#
#   openai api fine_tunes.follow -i ft-uxJUeShzlHhR97SQFEiI7UYg

# %%
# !openai api fine_tunes.follow -i ft-uxJUeShzlHhR97SQFEiI7UYg
# Out:
# [2023-02-28 13:41:18] Created fine-tune: ft-uxJUeShzlHhR97SQFEiI7UYg
# [2023-02-28 13:46:31] Fine-tune costs $3.98
# [2023-02-28 13:46:32] Fine-tune enqueued. Queue number: 4
# [2023-02-28 13:48:46] Fine-tune is in the queue. Queue number: 3
# [2023-02-28 13:48:51] Fine-tune is in the queue. Queue number: 2
# [2023-02-28 13:51:14] Fine-tune is in the queue. Queue number: 1
# [2023-02-28 13:51:38] Fine-tune is in the queue. Queue number: 0
# [2023-02-28 13:51:48] Fine-tune started
# [2023-02-28 13:54:59] Completed epoch 1/4
# [2023-02-28 13:55:49] Completed epoch 2/4
# [2023-02-28 13:56:39] Completed epoch 3/4
# [2023-02-28 13:57:29] Completed epoch 4/4
# [2023-02-28 13:58:05] Uploaded model: davinci:ft-personal:mental-health-model-2023-02-28-08-28-05
# [2023-02-28 13:58:06] Uploaded result file: file-MzBiSZNZ4aGdsFkvPNl0x6cz
# [2023-02-28 13:58:07] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# ...

# %%
# List all created fine-tunes
# !openai api fine_tunes.list

# Retrieve the state of a fine-tune. The resulting object includes
# job status (which can be one of pending, running, succeeded, or failed)
# and other information
# !openai api fine_tunes.get -i ada:ft-:mental-health-model-2022-12-26-06-44-14

# # Cancel a job
# openai api fine_tunes.cancel -i <YOUR_FINE_TUNE_JOB_ID>
# Out:
# {
#   "data": [
#     {
#       "created_at": 1672036882,
#       "fine_tuned_model": "ada:ft-:mental-health-model-2022-12-26-06-44-14",
#       "hyperparams": {
#         "batch_size": 1,
#         "learning_rate_multiplier": 0.1,
#         "n_epochs": 4,
#         "prompt_loss_weight": 0.01
#       },
#       "id": "ft-IW9e78IHIjWnKy8RCJd8noNL",
#       "model": "ada",
#       "object": "fine-tune",
#       "organization_id": "org-WllD8RlBChTIGy3XIVlNxKdt",
#       "result_files": [
#         {
#           "bytes": 21467,
#           "created_at": 1672037055,
#           "filename": "compiled_results.csv",
#           "id": "file-Egq5T0r3Eq0I2Gpjq5uQQe3Q",
#           "object": "file",
#           "purpose": "fine-tune-results",
#           "status": "processed",
#           "status_details": null
#         }
#       ],
#       "status": "succeeded",
#       "training_files": [
#         {
#           "bytes": 164692,
#           "created_at": 1672036882,
# ...

# %%
# import openai
# openai.Completion.create(
#     model=FINE_TUNED_MODEL,
#     prompt=YOUR_PROMPT)

# %%
import os
import openai

openai.api_key = os.getenv("OPENAI_API_KEY")

query = 'why mind stopped working after sleeping ->'

response = openai.Completion.create(
                #model= "ada:ft-:mental-health-model-2022-12-26-06-44-14",
                model= "davinci:ft-personal:mental-health-model-2023-02-28-08-28-05",
                prompt= query,
  #               # temperature=0.89,
                max_tokens=250,
  # #               top_p=1,
  # #               frequency_penalty=0,
  # #               presence_penalty=0.6,
  # #               stop=["\n"]
  )
print(response)
# Out:
# {
#   "choices": [
#     {
#       "finish_reason": "length",
#       "index": 0,
#       "logprobs": null,
# ...

# %%
# !openai api fine_tunes.results -i ft-IW9e78IHIjWnKy8RCJd8noNL >results.csv
